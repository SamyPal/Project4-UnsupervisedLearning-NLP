# %%
import datetime
import json
import pandas as pd

# %%
from nytimesarticle import articleAPI

# %%
articles = []
apikey = 'tT2Xe7XKy4dmY0JFfGZroTcM5IU2gZzu'
api = articleAPI(apikey)
article = api.search(q = 'TSLA', begin_date = 20181230)
print(len(article))
print(article['response'])
# Out:
# 3
# ...

# %%
article['response']['docs'][0]['snippet']
# Out:
# 'The electric-car maker and its chief, Elon Musk, head into a potentially crucial year on a positive note.'

# %%
df = pd.DataFrame(article['response']['docs'])
df.head()
# Out:
#                                             abstract  \
# 0  The electric-car maker and its chief, Elon Mus...
# 1  The automaker said its lowest-priced offering ...
# 2  The pay package Tesla promised to Elon Musk is...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2020/01/29/business/te...
# 1  https://www.nytimes.com/2019/04/12/business/te...
# 2  https://www.nytimes.com/interactive/2019/busin...
#
#                                              snippet  \
# 0  The electric-car maker and its chief, Elon Mus...
# 1  The automaker said its lowest-priced offering ...
# 2  The pay package Tesla promised to Elon Musk is...
#
#                                       lead_paragraph print_section print_page  \
# 0  Tesla said Wednesday that it turned a profit i...             B          4
# 1  Faced with slumping sales and increasing finan...             B          7
# 2  The pay package Tesla promised to Elon Musk is...           NaN        NaN
#
# ...

# %%
def parse_articles(articles):
    '''
    This function takes in a response to the NYT api and parses
    the articles into a list of dictionaries
    '''
    news = []
    for i in articles['response']['docs']:
        dic = {}
        dic['id'] = i['_id']
        if i['abstract'] is not None:
            dic['abstract'] = i['abstract'].encode("utf8")
        dic['headline'] = i['headline']['main'].encode("utf8")
        dic['desk'] = i['news_desk']
        dic['date'] = i['pub_date'][0:10] # cutting time of day.
        dic['section'] = i['section_name']
        if i['snippet'] is not None:
            dic['snippet'] = i['snippet'].encode("utf8")
        dic['source'] = i['source']
        dic['type'] = i['type_of_material']
        dic['url'] = i['web_url']
        dic['word_count'] = i['word_count']
        # locations
        locations = []
        for x in range(0,len(i['keywords'])):
            if 'glocations' in i['keywords'][x]['name']:
                locations.append(i['keywords'][x]['value'])
        dic['locations'] = locations
        # subject
        subjects = []
        for x in range(0,len(i['keywords'])):
            if 'subject' in i['keywords'][x]['name']:
                subjects.append(i['keywords'][x]['value'])
        dic['subjects'] = subjects   
        news.append(dic)
    return(news)
parse_articles(article)
# Out:
# [{'id': 'nyt://article/ac1aae5e-e124-5ac1-b351-b1bb45e2385c',
#   'abstract': b'The electric-car maker and its chief, Elon Musk, head into a potentially crucial year on a positive note.',
#   'headline': b'Tesla Posts $105 Million Profit for Quarter, Extending Rebound',
#   'desk': 'Business',
#   'date': '2020-01-29',
#   'section': 'Business Day',
#   'snippet': b'The electric-car maker and its chief, Elon Musk, head into a potentially crucial year on a positive note.',
#   'source': 'The New York Times',
#   'type': 'News',
#   'url': 'https://www.nytimes.com/2020/01/29/business/tesla-earnings.html',
#   'word_count': 845,
#   'locations': ['China'],
#   'subjects': ['Company Reports',
#    'Electric and Hybrid Vehicles',
#    'Factories and Manufacturing']},
#  {'id': 'nyt://article/e9c0d3ae-2f1e-5218-a718-52ee26b267bc',
# ...

# %%
def get_articles(date,query):
    '''
    This function accepts a year in string format (e.g.'1980')
    and a query (e.g.'Amnesty International') and it will 
    return a list of parsed articles (in dictionaries)
    for that year.
    '''
    all_articles = []
    for i in range(0,100): #NYT limits pager to first 100 pages. But rarely will you find over 100 pages of results anyway.
        articles = api.search(q = query,
               fq = {'source':['Reuters','AP', 'The New York Times']},
               begin_date = date + '0101',
               end_date = date + '1231',
               sort='oldest',
               page = str(i))
        articles = parse_articles(articles)
        all_articles = all_articles + articles
    return(all_articles)

# %%
Amnesty_all = []
for i in range(2019,2020):
    print ('Processing' + str(i) + '...')
    Amnesty_year =  get_articles(str(i),'Amnesty+International')
    Amnesty_all.append(Amnesty_year)
# Out:
# Processing2019...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-8990830b3249> in <module>
#       2 for i in range(2019,2020):
#       3     print ('Processing' + str(i) + '...')
# ----> 4     Amnesty_year =  get_articles(str(i),'Amnesty+International')
#       5     Amnesty_all.append(Amnesty_year)
#
# <ipython-input-35-ccc4f22d5cdc> in get_articles(date, query)
#      13                end_date = date + '1231',
#      14                sort='oldest',
# ---> 15                page = str(i))
#      16         articles = parse_articles(articles)
#      17         all_articles = all_articles + articles
#
# ~/opt/miniconda3/lib/python3.7/site-packages/nytimesarticle.py in search(self, response_format, key, **kwargs)
#     109
#     110         url = '%s%s?%sapi-key=%s' % (
# --> 111             API_ROOT, response_format, self._options(**kwargs), key
# ...

# %%
import csv
keys = Amnesty_all[0].keys()
with open('amnesty-mentions.csv', 'wb') as output_file:
    dict_writer = csv.DictWriter(output_file, keys)
    dict_writer.writeheader()
    dict_writer.writerows(Amnesty_all)
